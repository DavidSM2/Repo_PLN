# %% [markdown]
# # Pràctica 2 de PLN: web scraping
# En aquesta pràctica realitzarem diferents exercicis sobre captura de continguts web (*web scraping*) usant les llibreries `request` i `BeautifulSoup`.

# %% [markdown]
# ### Noms:
# Introdueix en esta celda els noms dels integrats del grup:\
# *Alumne 1* \
# *Alumne 2*

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Part 1: captura d'una notícia
# En aquest apartat ens descarregarem una notícia d'una pàgina web i guardem el seu contingut en memòria.

# %%
url = "https://elpais.com/sociedad/2019/11/13/actualidad/1573632952_315974.html"
try:
    page = requests.get(url)
except:
    print("Error al abrir la URL")

# %%
# parseamos el html usando BeautifulSoup y lo guardamos en la variable `soup`
soup = BeautifulSoup(page.text, 'html.parser')

# %% [markdown]
# El contingut de l'article (text del cos) es troba dins d'un `<div>` de la pàgina amb les classes `a_c clearfix` (pots inspeccionar l'estructura HTML de la pàgina en el navegador per a comprovar-lo)

# %%
# Buscamos el <div> correspondiente y sacamos su contenido:
content = soup.find('div', {"class": "a_c clearfix"})

article = []
for i in content.find_all('p'):
    article.append(i.text)
    
print('\n'.join(article))
# Out:
# Los venecianos viven en esta época del año refrescando cada minuto la aplicación del Centro de Previsión de Mareas, que permite saber hasta qué nivel puede llegar el acqua alta. El martes había luna llena y muchos se temieron lo peor, pero se fueron a cenar con el último dato de 140 centímetros. Pasadas las diez empezaron a sonar las sirenas. Un viento de más de 120 kilómetros por hora formó un pequeño maremoto en la laguna que provocó una subida de hasta 187 centímetros, la mayor desde la histórica catástrofe de 1966. Muchas de las 71 góndolas de la Riva Degli Schiavoni rompieron las amarras y salieron flotando hasta dar contra las columnas del Palacio Ducal. Algunos barrios se quedaron a oscuras y el agua entró violentamente en la basílica de San Marcos. Luego comenzó una subida por toda la isla que causó dos muertos, anegó restaurantes, palacios y comercios y obligó a cerrar escuelas. La ciudad está en alerta hasta el viernes por riesgo de que este episodio se repita.
# La ciudad empieza a estar harta de algo que todo el mundo cree que se podría evitar. Los efectos del cambio climático, que han aumentado la frecuencia y la intensidad de las tradicionales mareas de otoño (el año pasado sucedió algo parecido), un fuerte temporal y la negligencia en la construcción de un sistema de diques que dura ya 40 años dejaron la segunda peor inundación del siglo. Los daños en el patrimonio artístico de la ciudad de 1966 no se repitieron: los venecianos toman ya grandes precauciones en estas épocas. Pero este miércoles por la mañana, en medio de un paisaje apocalíptico con vaporetos y lanchas sobre la acera, podían verse todavía los efectos en la vida de la gente. El primer ministro, Giuseppe Conte, ha llegado a la ciudad por la tarde y ha asegurado que tomará medidas. “Hay una petición del gobernador Zaia para declarar el estado de emergencia y no veo razones para negarlo. Prepararemos los primeros fondos para la participación del Gobierno en esta emergencia”, ha dicho. Y la ministra de Infraestructuras y Transportes, Paola de Micheli, ha anunciado que se convocará un comité para tomar decisiones de largo recorrido en Venecia. “Haremos un gran proyecto para Venecia”.
# Los vecinos ya no creen en las promesas políticas. Marco Gazzetta achicaba agua en su negocio de máscaras junto a la plaza Rialto. Cuando fue a abrir por la mañana sabía que encontraría todo el género flotando. “La app nos dio otro resultado. Nos fuimos a casa pensando que no superaría los 140 centímetros”, protestaba. Katia, en un negocio de bisutería, les excusaba. “No es culpa suya, el viento lo cambió todo. No sé cómo se puede prevenir algo así”. El recuerdo de la terrible inundación del 4 de noviembre de 1966 comenzó a materializarse a las 21.00. A esa hora, un viento superior al previsto se levantó, empujando con fuerza el agua del Adriático a la laguna de Venecia. El Centro de Previsión de las Mareas de Venecia no acertó con la previsión. A las 22.40 la marea era de 180 centímetros y a las 23.00 alcanzaba ya los 187. Un técnico de dicho organismo asegura a este periódico que “se formó un pequeño ciclón sobre Venecia, con vientos de hasta 120 kilómetros por hora que empeoraron la situación”. “Es algo muy anómalo y puede estar relacionado con el cambio climático”, apunta.
# Javier Jordà, científico del Instituto Español de Oceanografía en Baleares y autor de una investigación que muestra cómo la subida del nivel del mar haría aumentar la frecuencia de inundaciones en Venecia a final de siglo, coincide y vincula lo que está ocurriendo al calentamiento: “Lo que antes pasaba una vez, se convertirá en norma. Hay que tener en cuenta que al incremento del nivel del mar se suma que la ciudad se está hundiendo, lo que hace que el efecto de la subida del agua se multiplique”.
# El nivel del mar en noviembre
# en Venecia
# Mediciones en la Punta della Salute en metros
# Tamaño
# comparativo
# 1,80 m
# 2,0
# 22.50
# 1,87 m
# 1,5
# 1,0
# 0,5
# 0,0
# Día 1
# 5
# 10
# 13
# Previsiones para los próximos días
# Tamaño
# comparativo
# 1,80 m
# 2,0
# 1,5
# 1,0
# 0,5
# 0,0
# 13
# 14
# 15
# 16
# 17 nov.
# Fuente: Comune di Venezia.
# Y. Clemente / EL PAÍS
# El nivel del mar en noviembre en Venecia
# Mediciones en la Punta della Salute
# Tamaño
# comparativo
# 1,80 m
# Metros
# 2,0
# 22.50
# 1,87 m
# 1,5
# 1,0
# 0,5
# 0,0
# Día 1
# 5
# 10
# 13
# Previsiones para los próximos días
# Tamaño
# comparativo
# 1,80 m
# Metros
# 2,0
# 1,5
# 1,0
# 0,5
# 0,0
# 13
# 14
# 15
# 16
# 17 nov.
# Fuente: Comune di Venezia.
# Y. Clemente / EL PAÍS
# El nivel del mar en noviembre en Venecia
# Mediciones en la Punta della Salute
# Previsiones para los
# próximos días
# Tamaño
# comparativo
# 1,80 m
# Metros
# 2,0
# 22.50
# 1,87 m
# 1,5
# 1,0
# 0,5
# 0,0
# 13
# 14
# 15
# 16
# 17 nov.
# Día 1
# 5
# 10
# 13
# Fuente: Comune di Venezia.
# Y. Clemente / EL PAÍS
# Los daños en viviendas y comercios fueron enormes. “Centenares de miles de euros”, denunció el alcalde de la ciudad, Luigi Brugnaro, que pidió declarar el estado de emergencia. Pero la peor parte, como sucedió ya el año pasado, se la llevó la basílica de San Pedro, que se encuentra en la parte más baja de la isla y es incapaz de contener las embestidas del agua. El templo bizantino, que se inundó por sexta vez en 1.200 años, tuvo que evacuar a los fieles al término de la misa de las ocho, explica su director, Giuseppe Marieschi, mientras muestra pedazos de los mosaicos arrancados del suelo y la base de las columnas de mármol carcomidas por la sal del agua de marina. “Si eso pasase una vez cada 100 años, sería un problema. Pero si pasa varias veces en una década es un riesgo enorme para la iglesia”, señala. La cripta, donde están las sepulturas de algunos de los patriarcas, quedó completamente inundada. “Los daños son irreparables”, advirtió el patriarca de Venecia, Francesco Moraglia.
# Javier Jordà, científico del Instituto Español de Oceanografía en Baleares y autor de una investigación que muestra cómo la subida del nivel del mar haría aumentar la frecuencia de inundaciones en Venecia a final de siglo, coincide y vincula lo que está ocurriendo al calentamiento: “Lo que antes pasaba una vez, se convertirá en norma. Hay que tener en cuenta que al incremento del nivel del mar se suma que la ciudad se está hundiendo, lo que hace que el efecto de la subida del agua se multiplique”.
# Los daños en viviendas y comercios fueron enormes. “Centenares de miles de euros”, denunció el alcalde de la ciudad, Luigi Brugnaro, que pidió declarar el estado de emergencia. Pero la peor parte, como sucedió ya el año pasado, se la llevó la basílica de San Pedro, que se encuentra en la parte más baja de la isla y es incapaz de contener las embestidas del agua. El templo bizantino, que se inundó por sexta vez en 1.200 años, tuvo que evacuar a los fieles al término de la misa de las ocho, explica su director, Giuseppe Marieschi, mientras muestra pedazos de los mosaicos arrancados del suelo y la base de las columnas de mármol carcomidas por la sal del agua de marina. “Si eso pasase una vez cada 100 años, sería un problema. Pero si pasa varias veces en una década es un riesgo enorme para la iglesia”, señala. La cripta, donde están las sepulturas de algunos de los patriarcas, quedó completamente inundada. “Los daños son irreparables”, advirtió el patriarca de Venecia, Francesco Moraglia.
# El ingeniero jefe de la basílica, Pierpaolo Campostrini, fue aún más directo. “Es una indecencia. El martes por la mañana, cuando la marea era de 140 centímetros se debió probar el Mose (acrónimo de Módulo Experimental Electromecánico). Se habría evitado el desastre en la basílica. La marea ha demostrado que Venecia no es segura. Esto es casi como el Apocalipsis, estuvimos al borde del desastre. El mar entró e inundó el suelo y los mosaicos, rompió ventanas e inundó la cripta. Más allá de los daños en el suelo y los mosaicos, el agua podría crear problemas de estabilidad en las columnas que sostienen el edificio”, advirtió.
# Los responsables de la basílica están valorando pedir la construcción de una suerte de barrera que pueda frenar el agua en caso de inundaciones en la plaza de San Marcos, revela Capostrini. Un atajo, en suma, para resolver la parálisis en la que lleva sumida la finalización del sistema de contención de las inundaciones, que resume cuatro décadas de despropósitos y corrupción. En 2003 se empezaron a construir 78 diques flotantes en el marco del proyecto Mose. Las esclusas deberían cerrar la laguna en caso de subida de las aguas del Adriático. Pero problemas de sobrecostes y corrupción retrasaron su puesta en funcionamiento. Hasta entonces, los venecianos solo podrán encomendarse al cielo o seguir refrescando aplicación de las mareas antes de cerrar sus negocios o irse a la cama.
# Con información de Esther Sánchez.

# %% [markdown]
# Si volguérem fer un filtrat més específic de paràgrafs o continguts, podem definir una funció lògica que retorne a `find_all` els elements a considerar:
# ```python
# def has_class_but_no_id(tag):
#     return tag.has_attr('class') and not tag.has_attr('id')
# ```
#
# Que després usem amb:
#
# ```python
# content.find_all(has_class_but_no_id)
# ```

# %%
#Por ejemplo los párrafos que contienen la palabra basílica
def contiene_basilica(tag):
# %% [markdown]
# ### Exercici 1
# Cerca els paràgrafs dins de l'etiqueta `<div>` amb el cos de la notícia que continguen un element de tipus enllace (`<a>`)

# %%
#Por ejemplo los párrafos que contienen la palabra basílica
def tipo_a(tag):
    return tag.name=='a'

content = soup.find('div', {"class": "a_c clearfix"})
content.find_all(tipo_a)
# Out:
# [<a href="https://elpais.com/tag/cambio_climatico/a" target="_blank">cambio climático</a>,
#  <a class="_db _pr" href="https://elpais.com/elpais/2019/11/13/album/1573633185_469059.html#?rel=listaapoyo"><img class="_re lazyload a_m-h" decoding="auto" height="110" loading="lazy" src="https://imagenes.elpais.com/resizer/E2eDNTKJAJGk9pJRgf4EFRlgy0Q=/146x110/cloudfront-eu-central-1.images.arcpublishing.com/prisa/MOJW26QEBPC427WK5DVAEBJQLE.jpg" srcset="https://imagenes.elpais.com/resizer/E2eDNTKJAJGk9pJRgf4EFRlgy0Q=/146x110/cloudfront-eu-central-1.images.arcpublishing.com/prisa/MOJW26QEBPC427WK5DVAEBJQLE.jpg 414w,https://imagenes.elpais.com/resizer/hpqhTKBm00daJopI36X6iuOOMqo=/292x219/cloudfront-eu-central-1.images.arcpublishing.com/prisa/MOJW26QEBPC427WK5DVAEBJQLE.jpg 640w" width="146"/></a>,
#  <a class="a_mi_e _db" href="https://elpais.com/elpais/2019/11/13/album/1573633185_469059.html#?rel=listaapoyo">Las inundaciones en Venecia, en imágenes</a>,
#  <a class="a_mi_e _db" href="https://elpais.com/cultura/2017/08/23/actualidad/1503509938_525170.html#?rel=listaapoyo">El día en que Venecia se ahogó</a>,
#  <a href="https://t.co/gS63ZK2j3Q">pic.twitter.com/gS63ZK2j3Q</a>,
#  <a href="https://twitter.com/LuigiBrugnaro/status/1194395095111491586?ref_src=twsrc%5Etfw">November 12, 2019</a>,
#  <a href="https://elpais.com/sociedad/2019/11/13/actualidad/1573656253_882619.html" target="_blank">se debió probar el Mose (acrónimo de Módulo Experimental Electromecánico).</a>,
#  <a data-link-am="https://elpais.com/subscriptions/#/sign-in?prod=REGCRART&amp;o=cerradoam&amp;prm=signwall_articulo_login_el-pais-america&amp;backURL=https%3A%2F%2Felpais.com%2Fsociedad%2F2019%2F11%2F13%2Factualidad%2F1573632952_315974.html" data-link-ar="https://elpais.com/subscriptions/#/sign-in?prod=REGCRART&amp;o=cerrado&amp;prm=signwall_articulo_login_el-pais&amp;backURL=https%3A%2F%2Felpais.com%2Fsociedad%2F2019%2F11%2F13%2Factualidad%2F1573632952_315974.html" data-link-ch="https://elpais.com/subscriptions/#/sign-in?prod=REGCRART&amp;o=cerrado&amp;prm=signwall_articulo_login_el-pais&amp;backURL=https%3A%2F%2Felpais.com%2Fsociedad%2F2019%2F11%2F13%2Factualidad%2F1573632952_315974.html" data-link-co="https://elpais.com/subscriptions/#/sign-in?prod=REGCRARTCLB&amp;o=cerradoclb&amp;prm=signwall_articulo_login_el-pais&amp;backURL=https%3A%2F%2Felpais.com%2Fsociedad%2F2019%2F11%2F13%2Factualidad%2F1573632952_315974.html" data-link-mx="https://elpais.com/subscriptions/#/sign-in?prod=REGCRART&amp;o=cerradomx&amp;prm=signwall_articulo_login_el-pais-mexico&amp;backURL=https%3A%2F%2Felpais.com%2Fsociedad%2F2019%2F11%2F13%2Factualidad%2F1573632952_315974.html" href="https://elpais.com/subscriptions/#/sign-in?prod=REGCRART&amp;o=cerrado&amp;prm=signwall_articulo_login_el-pais&amp;backURL=https%3A%2F%2Felpais.com%2Fsociedad%2F2019%2F11%2F13%2Factualidad%2F1573632952_315974.html"><button class="btn btn-7">INICIA SESIÓN</button></a>,
#  <a data-link-am="https://elpais.com/subscriptions/#/register?prod=REGCRART&amp;o=cerradoam&amp;prm=signwall_articulo_registro_el-pais-america&amp;backURL=https%3A%2F%2Felpais.com%2Fsociedad%2F2019%2F11%2F13%2Factualidad%2F1573632952_315974.html" data-link-ar="https://elpais.com/subscriptions/#/register?prod=REGCRART&amp;o=cerrado&amp;prm=signwall_articulo_registro_el-pais&amp;backURL=https%3A%2F%2Felpais.com%2Fsociedad%2F2019%2F11%2F13%2Factualidad%2F1573632952_315974.html" data-link-ch="https://elpais.com/subscriptions/#/register?prod=REGCRART&amp;o=cerrado&amp;prm=signwall_articulo_registro_el-pais&amp;backURL=https%3A%2F%2Felpais.com%2Fsociedad%2F2019%2F11%2F13%2Factualidad%2F1573632952_315974.html" data-link-co="https://elpais.com/subscriptions/#/register?prod=REGCRARTCLB&amp;o=cerradoclb&amp;prm=signwall_articulo_registro_el-pais&amp;backURL=https%3A%2F%2Felpais.com%2Fsociedad%2F2019%2F11%2F13%2Factualidad%2F1573632952_315974.html" data-link-mx="https://elpais.com/subscriptions/#/register?prod=REGCRART&amp;o=cerradomx&amp;prm=signwall_articulo_registro_el-pais-mexico&amp;backURL=https%3A%2F%2Felpais.com%2Fsociedad%2F2019%2F11%2F13%2Factualidad%2F1573632952_315974.html" href="https://elpais.com/subscriptions/#/register?prod=REGCRART&amp;o=cerrado&amp;prm=signwall_articulo_registro_el-pais&amp;backURL=https%3A%2F%2Felpais.com%2Fsociedad%2F2019%2F11%2F13%2Factualidad%2F1573632952_315974.html"><button class="btn btn-6">REGÍSTRATE</button></a>,
#  <a class="button | flex" data-ctn-subscription="" data-link-am="https://elpais.com/suscripciones/america/#/campaign#?prod=SUSDIGCRARTAM&amp;o=cerradoam&amp;prm=signwall_articulo_landing_el-pais-america&amp;backURL=https%3A%2F%2Felpais.com%2Fsociedad%2F2019%2F11%2F13%2Factualidad%2F1573632952_315974.html" data-link-ar="https://elpais.com/suscripciones/america/#/campaign#?prod=SUSDIGCRARTAR&amp;o=cerrado&amp;prm=signwall_articulo_landing_el-pais&amp;backURL=https%3A%2F%2Felpais.com%2Fsociedad%2F2019%2F11%2F13%2Factualidad%2F1573632952_315974.html" data-link-ch="https://elpais.com/suscripciones/america/#/campaign#?prod=SUSDIGCRARTCHILE&amp;o=cerrado&amp;prm=signwall_articulo_landing_el-pais&amp;backURL=https%3A%2F%2Felpais.com%2Fsociedad%2F2019%2F11%2F13%2Factualidad%2F1573632952_315974.html" data-link-co="https://elpais.com/suscripciones/america/#/campaign#?prod=SUSDIGCRARTCOL&amp;o=cerradoclb&amp;prm=signwall_articulo_landing_el-pais&amp;backURL=https%3A%2F%2Felpais.com%2Fsociedad%2F2019%2F11%2F13%2Factualidad%2F1573632952_315974.html" data-link-mx="https://elpais.com/suscripciones/america/#/campaign#?prod=SUSDIGCRARTMX&amp;o=cerradomx&amp;prm=signwall_articulo_landing_el-pais-mexico&amp;backURL=https%3A%2F%2Felpais.com%2Fsociedad%2F2019%2F11%2F13%2Factualidad%2F1573632952_315974.html" href="https://elpais.com/suscripciones/#/campaign#?prod=SUSDIGCRART&amp;o=cerrado&amp;prm=signwall_articulo_landing_el-pais&amp;backURL=https%3A%2F%2Felpais.com%2Fsociedad%2F2019%2F11%2F13%2Factualidad%2F1573632952_315974.html">O suscríbete para leer sin límites</a>]

# %% [markdown]
# ## Part 2: captura de dades meteorològiques
# En aquest apartat capturarem dades meteorològiques de la Comunitat Valenciana des de la pàgina de la [AVAMET (Associació valenciana de meteorologia)](https://www.avamet.org).

# %%
#esta página contiene los datos meteorológicos de un día concreto
fecha = '2021-02-10'
r = requests.get("https://www.avamet.org/mx-meteoxarxa.php", params={'id':fecha})

# %%
soup = BeautifulSoup(r.text, "html.parser")

# %% [markdown]
# Les dades de tots els municipis de la CV estan en una taula de classe `tDades`

# %%
tabla = soup.find("table", class_="tDades")

# %% [markdown]
# Dins de la taula, les dades estan en les files (`<tr>`) que tenen un element`<td class='rEsta'>`. Definim una funció per a filtrar etiquetes amb aquesta classe i busquem tots els elements interns a la taula:

# %%
def clase_rEsta(tag):
    return tag.find(class_="rEsta")

# %%
loc = tabla.find_all(clase_rEsta)

# %%
len(loc)
# Out:
# 656

# %% [markdown]
# Ens fixem per exemple en el primer element d'aquesta llista:

# %%
print(loc[0].prettify())
# Out:
# <tr>
#  <td class="rEsta">
#   <a class="negre" href="mx-fitxa.php?id=c01m038e20">
#    <img alt="" height="13" src="imatges/2017/clas/estrela-mx-.png" title="" width="13">
#     Castellfort
#     <span class="rEstaDmxo">
#      <span class="ptda">
#      </span>
#      AEMET
#     </span>
#    </img>
#   </a>
#  </td>
#  <td class="rValm colornT16">
#   2,4
#  </td>
#  <td class="rValm colornT17">
#   4,7
#  </td>
#  <td class="rValm colornT18">
#   7,0
#  </td>
#  <td class="rVal">
#  </td>
#  <td class="rValm colorP">
#   0,0
#  </td>
#  <td class="rVal">
#  </td>
#  <td class="rVal">
#  </td>
#  <td class="rVal">
#   <b>
#   </b>
#  </td>
# </tr>

# %% [markdown]
# Veiem que algunes de les cel·les d'aquesta fila tenen elements de tipus `<span>`. Si no ens interessen els podríem eliminar amb el mètode `,decompose()` del Tag. Però com el text ens interessa fiquem un espai per a separar el contingut en extraure el text posteriorment amb `.text()`:

# %%
for t in loc:
    for t in t.find_all('span', class_="rEstaDmxo"):
        t.insert_before(' ')
print(loc[0].prettify())
# Out:
# <tr>
#  <td class="rEsta">
#   <a class="negre" href="mx-fitxa.php?id=c01m038e20">
#    <img alt="" height="13" src="imatges/2017/clas/estrela-mx-.png" title="" width="13">
#     Castellfort
#     <span class="rEstaDmxo">
#      <span class="ptda">
#      </span>
#      AEMET
#     </span>
#    </img>
#   </a>
#  </td>
#  <td class="rValm colornT16">
#   2,4
#  </td>
#  <td class="rValm colornT17">
#   4,7
#  </td>
#  <td class="rValm colornT18">
#   7,0
#  </td>
#  <td class="rVal">
#  </td>
#  <td class="rValm colorP">
#   0,0
#  </td>
#  <td class="rVal">
#  </td>
#  <td class="rVal">
#  </td>
#  <td class="rVal">
#   <b>
#   </b>
#  </td>
# </tr>

# %%
#Cada celda <td> dentro de la fila es una columna de la tabla
[t.text.strip() for t in loc[0].find_all("td")]
# Out:
# ['Castellfort AEMET', '2,4', '4,7', '7,0', '', '0,0', '', '', '']

# %%
[t for t in loc[0].find_all("td")]
# Out:
# [<td class="rEsta"><a class="negre" href="mx-fitxa.php?id=c01m038e20"><img alt="" height="13" src="imatges/2017/clas/estrela-mx-.png" title="" width="13"> Castellfort <span class="rEstaDmxo"><span class="ptda"></span>AEMET</span></img></a> </td>,
#  <td class="rValm colornT16">2,4 </td>,
#  <td class="rValm colornT17">4,7 </td>,
#  <td class="rValm colornT18">7,0 </td>,
#  <td class="rVal"> </td>,
#  <td class="rValm colorP">0,0 </td>,
#  <td class="rVal"> </td>,
#  <td class="rVal"> </td>,
#  <td class="rVal"><b> </b></td>]

# %%
#Capturamos toda la tabla
datos = [[t.text.strip() for t in l.find_all("td")] for l in loc]

# %%
#Todas las filas tienen los mismos datos
[len(d) for d in datos]
# Out:
# [9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9]

# %% [markdown]
# Ara exportem la taula com un DataFrame de `pandas`:

# %%
import pandas as pd

# %%
data_matrix = pd.DataFrame(datos, columns = ['localidad','Temp','Tmax','Tmin','Humedad','Precip',
                      'Vel.viento','Dir.viento','Vmax_viento']) #Definimos el nombre de las columnas

# %%
data_matrix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 656 entries, 0 to 655
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   localidad    656 non-null    object
#  1   Temp         656 non-null    object
#  2   Tmax         656 non-null    object
#  3   Tmin         656 non-null    object
#  4   Humedad      656 non-null    object
#  5   Precip       656 non-null    object
#  6   Vel.viento   656 non-null    object
#  7   Dir.viento   656 non-null    object
#  8   Vmax_viento  656 non-null    object
# dtypes: object(9)
# memory usage: 46.2+ KB

# %%
data_matrix.head(5)
# Out:
#                localidad Temp Tmax  Tmin Humedad Precip Vel.viento Dir.viento  \
# 0      Castellfort AEMET  2,4  4,7   7,0            0,0
# 1             Cinctorres  4,4  7,4   9,9      61    0,6       16,9         NO
# 2                Forcall  1,6  7,9  12,3      64    0,8        9,2         NO
# 3         Morella centre  4,4  7,4  10,6      64    1,2       10,6          O
# 4  Morella Fàbrica Giner  0,6  7,8  11,4      66    1,2        2,4          O
#
#   Vmax_viento
# 0
# 1        74,0
# 2        51,5
# 3        56,3
# 4        35,4

# %% [markdown]
# També podíem llegir directament la taula en pandas amb el mètode `read_HTML`

# %%
#hace falta instalar la librería 'lxml'
df = pd.read_html(str(tabla))[0] #devuelve una lista de dataframes
df.head(10)
# Out:
#                        Estació       Temperatura (°C)                         \
#                        Estació                    Mín                    Mit
# 0        Província de Castelló  Província de Castelló  Província de Castelló
# 1                    els Ports              els Ports              els Ports
# 2            Castellfort AEMET                     24                     47
# 3                   Cinctorres                     44                     74
# 4                      Forcall                     16                     79
# 5               Morella centre                     44                     74
# 6        Morella Fàbrica Giner                     06                     78
# 7   Morella Poliesportiu AEMET                     37                     65
# 8  Olocau del Rei la Magdalena                     30                     55
# 9           Portell de Morella                     42                     69
#
#                                          HR (%)             Prec. (mm)  \
#                      Màx                    Mit             Prec. (mm)
# 0  Província de Castelló  Província de Castelló  Província de Castelló
# 1              els Ports              els Ports              els Ports
# 2                     70                    NaN                     00
# 3                     99                     61                     06
# 4                    123                     64                     08
# 5                    106                     64                     12
# 6                    114                     66                     12
# 7                     94                    NaN                     14
# 8                     91                     69                     08
# 9                     96                     63                     02
#
#                     Vent
#                      Mit                    Dir    Màx
# 0  Província de Castelló  Província de Castelló    NaN
# 1              els Ports              els Ports    NaN
# 2                    NaN                    NaN    NaN
# 3                    169                     NO  740.0
# 4                     92                     NO  515.0
# 5                    106                      O  563.0
# 6                     24                      O  354.0
# 7                    NaN                    NaN  850.0
# 8                    330                    ONO  853.0
# 9                    206                    ONO  692.0

# %% [markdown]
# ### Exercici 2
# Crea un script per a capturar les dades d'un territori i una data concretes a través de la URL:\
# `https://www.avamet.org/mx-meteoxarxa.php?id={fecha}&territori={territorio}`\
# Els codis de cada territori estan en l'element `select` següent:

# %%
select = soup.find("select", attrs={'name':"freg_territori"})

# %%
#r = requests.get("https://www.avamet.org/mx-meteoxarxa.php", params={'id':fecha, 'territori': 'c03'})
valores = select.findAll("option")
df2 = pd.DataFrame()

for valor in valores :
    r2 = requests.get("https://www.avamet.org/mx-meteoxarxa.php", params={'id':fecha, 'territori': valor["value"]})
    soup2 = BeautifulSoup(r.text, "html.parser")
    tabla2 = soup2.find("table", class_="tDades")
    df_aux = pd.read_html(str(tabla2))[0]
    df2 = pd.concat([df2 ,df_aux])

df2
# Out:
#                                             Estació  \
#                                             Estació
# 0                             Província de Castelló
# 1                                         els Ports
# 2                                  CastellfortAEMET
# 3                                        Cinctorres
# 4                                           Forcall
# ..                                              ...
# 696                           Torremocha del Jiloca
# 697               Monteagudo del CastilloEl Portero
# 698                                      Bronchales
# 699  Província de Województwo małopolskie (Polònia)
# 700              Czarny DunajecPuścizna Rękowiańska
#
#                                    Temperatura (°C)  \
#                                                 Mín
# 0                             Província de Castelló
# 1                                         els Ports
# 2                                                24
# 3                                                44
# 4                                                16
# ..                                              ...
# 696                                             -14
# 697                                             -43
# 698                                             -04
# 699  Província de Województwo małopolskie (Polònia)
# 700                                            -157
#
#                                                      \
#                                                 Mit
# 0                             Província de Castelló
# 1                                         els Ports
# 2                                                47
# 3                                                74
# 4                                                79
# ..                                              ...
# 696                                              50
# 697                                              19
# 698                                              13
# 699  Província de Województwo małopolskie (Polònia)
# 700                                             -49
#
#                                                      \
#                                                 Màx
# 0                             Província de Castelló
# 1                                         els Ports
# 2                                                70
# 3                                                99
# 4                                               123
# ..                                              ...
# 696                                             111
# 697                                              71
# 698                                              36
# 699  Província de Województwo małopolskie (Polònia)
# 700                                             -11
#
#                                              HR (%)  \
#                                                 Mit
# 0                             Província de Castelló
# 1                                         els Ports
# 2                                               NaN
# 3                                                61
# 4                                                64
# ..                                              ...
# 696                                              75
# 697                                              81
# 698                                              88
# 699  Província de Województwo małopolskie (Polònia)
# 700                                             NaN
#
#                                          Prec. (mm)  \
#                                          Prec. (mm)
# 0                             Província de Castelló
# 1                                         els Ports
# 2                                                00
# 3                                                06
# 4                                                08
# ..                                              ...
# 696                                              22
# 697                                              16
# 698                                              42
# 699  Província de Województwo małopolskie (Polònia)
# 700                                             NaN
#
#                                                Vent  \
#                                                 Mit
# 0                             Província de Castelló
# 1                                         els Ports
# 2                                               NaN
# 3                                               169
# 4                                                92
# ..                                              ...
# 696                                             130
# 697                                             140
# 698                                             352
# 699  Província de Województwo małopolskie (Polònia)
# 700                                              00
#
#
#                                                 Dir    Màx
# 0                             Província de Castelló    NaN
# 1                                         els Ports    NaN
# 2                                               NaN    NaN
# 3                                                NO  740.0
# 4                                                NO  515.0
# ..                                              ...    ...
# 696                                              NO  547.0
# 697                                             NNE  440.0
# 698                                               O  917.0
# 699  Província de Województwo małopolskie (Polònia)    NaN
# 700                                               N    0.0
#
# [26638 rows x 9 columns]

# %% [markdown]
# ### exercici extra:
# Captura les dades durant un mes de l'estació de 'València *Camins al Grau' i representa gràficament la seua temperatura mitjana

# %%
# Solución

# %% [markdown]
# ## Part 3: dades de la Wikipedia
# En aquesta part obtindrem les URL de les entrades en la Wikipedia per a totes les províncies d'Espanya i obtindrem d'elles les seues dades bàsiques en forma de taula.\
# El llistat de les províncies d'Espanya es pot descarregar de la pàgina de la Wikipedia següent:\
# https://es.wikipedia.org/wiki/Provincia_(España)

# %%
r = requests.get("https://es.wikipedia.org/wiki/Provincia_(España)")
soup = BeautifulSoup(r.text, "html.parser")

# %%
tabla = soup.find("table", class_="wikitable")

# %%
#todas las filas de la tabla (<tr>)
provincias = tabla.find_all("tr")

# %%
#los datos están en la primera celda <td> de cada fila a partir de la 1 (la fila 0 son los encabezados)
print(provincias[1].td.prettify())
# Out:
# <td>
#  <a href="/wiki/%C3%81lava" title="Álava">
#   Álava
#  </a>
# </td>

# %%
# extraemos el enlace
provincias[1].td.find("a")
# Out:
# <a href="/wiki/%C3%81lava" title="Álava">Álava</a>

# %%
enlaces = []
for p in provincias:
    if p.td:
        ref = p.td.find('a')
        enlaces.append(ref)

# %%
enlaces
# Out:
# [<a href="/wiki/%C3%81lava" title="Álava">Álava</a>,
#  <a href="/wiki/Provincia_de_Albacete" title="Provincia de Albacete">Albacete</a>,
#  <a href="/wiki/Provincia_de_Alicante" title="Provincia de Alicante">Alicante</a>,
#  <a href="/wiki/Provincia_de_Almer%C3%ADa" title="Provincia de Almería">Almería</a>,
#  <a class="mw-redirect" href="/wiki/Provincia_de_Asturias" title="Provincia de Asturias">Asturias</a>,
#  <a href="/wiki/Provincia_de_%C3%81vila" title="Provincia de Ávila">Ávila</a>,
#  <a href="/wiki/Provincia_de_Badajoz" title="Provincia de Badajoz">Badajoz</a>,
#  <a href="/wiki/Provincia_de_Barcelona" title="Provincia de Barcelona">Barcelona</a>,
#  <a href="/wiki/Provincia_de_Burgos" title="Provincia de Burgos">Burgos</a>,
#  <a href="/wiki/Provincia_de_C%C3%A1ceres" title="Provincia de Cáceres">Cáceres</a>,
#  <a href="/wiki/Provincia_de_C%C3%A1diz" title="Provincia de Cádiz">Cádiz</a>,
#  <a class="mw-redirect" href="/wiki/Provincia_de_
#  <a href="/wiki/Provincia_de_Valladolid" title="Provincia de Valladolid">Valladolid</a>,
#  <a href="/wiki/Vizcaya" title="Vizcaya">Vizcaya</a>,
#  <a href="/wiki/Provincia_de_Zamora" title="Provincia de Zamora">Zamora</a>,
#  <a href="/wiki/Provincia_de_Zaragoza" title="Provincia de Zaragoza">Zaragoza</a>]

# %%
enlaces_df = pd.DataFrame({'provincia': [e.attrs['title'] for e in enlaces],
                           'enlace': [e.attrs['href'] for e in enlaces]})

# %%
enlaces_df
# Out:
#                               provincia  \
# 0                                 Álava
# 1                 Provincia de Albacete
# 2                 Provincia de Alicante
# 3                  Provincia de Almería
# 4                 Provincia de Asturias
# 5                    Provincia de Ávila
# 6                  Provincia de Badajoz
# 7                Provincia de Barcelona
# 8                   Provincia de Burgos
# 9                  Provincia de Cáceres
# 10                   Provincia de Cádiz
# 11               Provincia de Cantabria
# 12               Provincia de Castellón
# 13             Provincia de Ciudad Real
# 14        Provincia de Córdoba (España)
# 15               Provincia de La Coruña
# 16                  Provincia de Cuenca
# 17                  Provincia de Gerona
# 18                 Provincia de Granada
# 19             Provincia de Guadalajara
# 20               Provincia de Guipúzcoa
# 21                  Provincia de Huelva
# 22                  Provincia de Huesca
# 23          Provincia de Islas Baleares
# 24           Provincia de Jaén (España)
# 25           Provincia de León (España)
# 26                  Provincia de Lérida
# 27                    Provincia de Lugo
# 28                  Provincia de Madrid
# 29                  Provincia de Málaga
# 30                  Provincia de Murcia
# 31                 Provincia de Navarra
# 32                  Provincia de Orense
# 33                Provincia de Palencia
# 34              Provincia de Las Palmas
# 35              Provincia de Pontevedra
# 36       Provincia de La Rioja (España)
# 37               Provincia de Salamanca
# 38                 Provincia de Segovia
# 39                 Provincia de Sevilla
# 40                   Provincia de Soria
# 41               Provincia de Tarragona
# 42  Provincia de Santa Cruz de Tenerife
# 43                  Provincia de Teruel
# 44                  Provincia de Toledo
# 45                Provincia de Valencia
# 46              Provincia de Valladolid
# 47                              Vizcaya
# 48                  Provincia de Zamora
# 49                Provincia de Zaragoza
#
#                                            enlace
# 0                                /wiki/%C3%81lava
# 1                     /wiki/Provincia_de_Albacete
# 2                     /wiki/Provincia_de_Alicante
# 3                 /wiki/Provincia_de_Almer%C3%ADa
# 4                     /wiki/Provincia_de_Asturias
# 5                   /wiki/Provincia_de_%C3%81vila
# 6                      /wiki/Provincia_de_Badajoz
# 7                    /wiki/Provincia_de_Barcelona
# 8                       /wiki/Provincia_de_Burgos
# 9                 /wiki/Provincia_de_C%C3%A1ceres
# 10                  /wiki/Provincia_de_C%C3%A1diz
# 11                   /wiki/Provincia_de_Cantabria
# 12              /wiki/Provincia_de_Castell%C3%B3n
# 13                 /wiki/Provincia_de_Ciudad_Real
# 14  /wiki/Provincia_de_C%C3%B3rdoba_(Espa%C3%B1a)
# 15              /wiki/Provincia_de_La_Coru%C3%B1a
# 16                      /wiki/Provincia_de_Cuenca
# 17                      /wiki/Provincia_de_Gerona
# 18                     /wiki/Provincia_de_Granada
# 19                 /wiki/Provincia_de_Guadalajara
# 20              /wiki/Provincia_de_Guip%C3%BAzcoa
# 21                      /wiki/Provincia_de_Huelva
# 22                      /wiki/Provincia_de_Huesca
# 23              /wiki/Provincia_de_Islas_Baleares
# 24     /wiki/Provincia_de_Ja%C3%A9n_(Espa%C3%B1a)
# 25     /wiki/Provincia_de_Le%C3%B3n_(Espa%C3%B1a)
# 26                 /wiki/Provincia_de_L%C3%A9rida
# 27                        /wiki/Provincia_de_Lugo
# 28                      /wiki/Provincia_de_Madrid
# 29                 /wiki/Provincia_de_M%C3%A1laga
# 30                      /wiki/Provincia_de_Murcia
# 31                     /wiki/Provincia_de_Navarra
# 32                      /wiki/Provincia_de_Orense
# 33                    /wiki/Provincia_de_Palencia
# 34                  /wiki/Provincia_de_Las_Palmas
# 35                  /wiki/Provincia_de_Pontevedra
# 36      /wiki/Provincia_de_La_Rioja_(Espa%C3%B1a)
# 37                   /wiki/Provincia_de_Salamanca
# 38                     /wiki/Provincia_de_Segovia
# 39                     /wiki/Provincia_de_Sevilla
# 40                       /wiki/Provincia_de_Soria
# 41                   /wiki/Provincia_de_Tarragona
# 42      /wiki/Provincia_de_Santa_Cruz_de_Tenerife
# 43                      /wiki/Provincia_de_Teruel
# 44                      /wiki/Provincia_de_Toledo
# 45                    /wiki/Provincia_de_Valencia
# 46                  /wiki/Provincia_de_Valladolid
# 47                                  /wiki/Vizcaya
# 48                      /wiki/Provincia_de_Zamora
# 49                    /wiki/Provincia_de_Zaragoza

# %% [markdown]
# Per exemple, creem el objecte `soup` per a la primera província:

# %%
r = requests.get("https://es.wikipedia.org"+enlaces_df['enlace'][0])
soup = BeautifulSoup(r.text, "html.parser")

# %% [markdown]
# Extraurem en un dataframe la informació geogràfica de la taula de la barra lateral dreta (atribut de classe `infobox`):

# %%
tabla = soup.find("table", class_="infobox")

# %% [markdown]
# Si inspecciones la seua estructura HTML veuràs una sèrie de tags `tr` de les quals pengen parells de tags `th` i `td` associades. Capturarem els seus textos en dues llistes: `dada` i `valor`, respectivamant.

# %%
dato, valor = [],[]
for t in tabla.find_all("tr"):
    if t.th:
        if t.td:
            dato.append(t.th.text)
            #valor.append(t.td.text) # aparecen caracteres especiales!
            valor.append(' '.join([text for text in t.td.stripped_strings]))

# %%
datos = pd.DataFrame({'Dato': dato, 'Valor': valor})
datos
# Out:
#                                                  Dato  \
# 0                                         Coordenadas
# 1                                             Capital
# 2                                      Idioma oficial
# 3                                             Entidad
# 4                                              • País
# 5                                         • Comunidad
# 6   CongresoSenadoParlamento VascoJuntas Generales...
# 7                                       Subdivisiones
# 8                                           Fundación
# 9                                          Superficie
# 10                                            • Total
# 11                                            Altitud
# 12                                            • Media
# 13                                           • Máxima
# 14                                           • Mínima
# 15                                              Clima
# 16                                   Población (2022)
# 17                                            • Total
# 18                                         • Densidad
# 19                                         Gentilicio
# 20                                      PIB (nominal)
# 21                                            • Total
# 22                                   • PIB per cápita
# 23                                         IDH (2007)
# 24                                      Código postal
# 25                                         ISO 3166-2
#
#                                                 Valor
# 0   42°50′00″N 2°45′00″O ﻿ / ﻿ 42.833333333333, -2.75
# 1                                             Vitoria
# 2                                   Español y euskera
# 3                                 Provincia de España
# 4                                              España
# 5                                          País Vasco
# 6   4 diputados 4 senadores 25 parlamentarios auto...
# 7                            7 comarcas 51 municipios
# 8                        División territorial de 1833
# 9                                         Puesto 48.º
# 10                                3037 km² ( 0,60 % )
# 11
# 12                                    ~650 m s. n. m.
# 13                       Monte Gorbea 1482 m s. n. m.
# 14               Río Cadagua en Oquendo 50 m s. n. m.
# 15                                           Oceánico
# 16                                        Puesto 36.º
# 17                            334 412 hab. ( 0,70 % )
# 18                                     109,85 hab/km²
# 19                   alavés, -a babazorro, -a [ 1 ] ​
# 20                                       Puesto 31 .º
# 21                              10 287 947 miles de €
# 22                                    33 112 € (2010)
# 23                           0,990 ( 2 .º) – Muy alto
# 24                                         01 [ 2 ] ​
# 25                                              ES-VI

# %% [markdown]
# ### Exercici 3
# Crea una taula (dataframe) amb la capital, la superfície i la població de cada província d'Espanya.\
# Per a trobar en la taula aquestes dades podem fer:

# %%
tabla.find(string='Capital').next.text
# Out:
# '\nVitoria'

# %%
tabla.find(string='Superficie').parent.parent.parent.next_sibling.text
# Out:
# '\xa0• Total\n3037 km²\xa0(0,60\xa0%)'

# %%
tabla.find(string='Población').parent.parent.parent.next_sibling.text
# Out:
# '\xa0• Total\n334\xa0412\xa0hab.\xa0(0,70\xa0%)'

# %% [markdown]
# Hauràs d'usar expressions regulars per a extraure d'aquests *strings el text buscat. Si la informació no està disponible per a alguna província, emplena la cel·la amb un *string* buit.

# %%
import re

lista = list()
for provincia in enlaces_df['enlace']:

    r2 = requests.get("https://es.wikipedia.org"+provincia)
    soup2 = BeautifulSoup(r2.text, "html.parser")
    tabla2 = soup2.find("table", class_="infobox")           
    #solución
    capital = tabla2.find(string='Capital').next.text.strip()
    superficie = re.findall(r'\d+ km²',tabla2.find(string='Superficie').parent.parent.parent.next_sibling.text)[0]
    poblacion = re.findall(r'([\d+\xa0]+hab)', tabla2.find(string='Población').parent.parent.parent.next_sibling.text)[0].replace('\xa0',' ')

    print(capital + " " + superficie + " " + poblacion + "\n")
    lista.append({'Capital': capital, 'Superficie': superficie, 'Poblacion': poblacion})
df3 = pd.DataFrame(lista)
# Out:
# Vitoria 3037 km² 334 412 hab
#
# Albacete 926 km² 386 464 hab
#
# Alicante 5816 km² 594 hab
#
# Almería 8774 km² 731 792 hab
#
# Oviedo43°31′46″N 5°40′38″O﻿ / ﻿43.52931, -5.67732 57 km² 1 004 499 hab
#
# Ávila 15 km² 158 421 hab
#
# Badajoz 766 km² 943 hab
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7220\3084293828.py in <module>
#       9     #solución
#      10     capital = tabla2.find(string='Capital').next.text.strip()
# ---> 11     superficie = re.findall(r'\d+ km²',tabla2.find(string='Superficie').parent.parent.parent.next_sibling.text)[0]
#      12     poblacion = re.findall(r'([\d+\xa0]+hab)', tabla2.find(string='Población').parent.parent.parent.next_sibling.text)[0].replace('\xa0',' ')
#      13
#
# IndexError: list index out of range
